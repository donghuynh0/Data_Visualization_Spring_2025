# %%
import pandas as pd
import json
import numpy as np

# %%
url = "http://115.78.93.252/TTU/pool/donghuynh0/data_visualization_2025/final_proejct/raw/women_results.csv"
continent_url = "http://115.78.93.252/TTU/pool/donghuynh0/data_visualization_2025/final_proejct/raw/continent_mapping.json"

# %%
df = pd.read_csv(url)

df
# Out:
#       Unnamed: 0        date home_team    away_team  home_score  away_score  \
# 0              0  1969-11-01     Italy       France           1           0
# 1              1  1969-11-01   Denmark      England           4           3
# 2              2  1969-11-02   England       France           2           0
# 3              3  1969-11-02     Italy      Denmark           3           1
# 4              4  1975-08-25  Thailand    Australia           3           2
# ...          ...         ...       ...          ...         ...         ...
# 4879        4879  2022-07-22    Sweden      Belgium           1           0
# 4880        4880  2022-07-23    France  Netherlands           1           0
# 4881        4881  2022-07-26   England       Sweden           4           0
# 4882        4882  2022-07-27   Germany       France           2           1
# 4883        4883  2022-07-31   England      Germany           2           1
#
#             tournament
# 0                 Euro
# 1                 Euro
# 2                 Euro
# 3                 Euro
# 4     AFC Championship
# ...                ...
# 4879         UEFA Euro
# 4880         UEFA Euro
# 4881         UEFA Euro
# 4882         UEFA Euro
# 4883         UEFA Euro
#
# [4884 rows x 7 columns]

# %%
# remove unneccesary column

df = df.drop('Unnamed: 0', axis=1)

df
# Out:
#             date home_team    away_team  home_score  away_score  \
# 0     1969-11-01     Italy       France           1           0
# 1     1969-11-01   Denmark      England           4           3
# 2     1969-11-02   England       France           2           0
# 3     1969-11-02     Italy      Denmark           3           1
# 4     1975-08-25  Thailand    Australia           3           2
# ...          ...       ...          ...         ...         ...
# 4879  2022-07-22    Sweden      Belgium           1           0
# 4880  2022-07-23    France  Netherlands           1           0
# 4881  2022-07-26   England       Sweden           4           0
# 4882  2022-07-27   Germany       France           2           1
# 4883  2022-07-31   England      Germany           2           1
#
#             tournament
# 0                 Euro
# 1                 Euro
# 2                 Euro
# 3                 Euro
# 4     AFC Championship
# ...                ...
# 4879         UEFA Euro
# 4880         UEFA Euro
# 4881         UEFA Euro
# 4882         UEFA Euro
# 4883         UEFA Euro
#
# [4884 rows x 6 columns]

# %%
continent_mapping = pd.read_json(continent_url, typ='series')

# %%
# map name of countries with respective continents

df['home_continent'] = df['home_team'].map(continent_mapping)
df['away_continent'] = df['away_team'].map(continent_mapping)

df
# Out:
#             date home_team    away_team  home_score  away_score  \
# 0     1969-11-01     Italy       France           1           0
# 1     1969-11-01   Denmark      England           4           3
# 2     1969-11-02   England       France           2           0
# 3     1969-11-02     Italy      Denmark           3           1
# 4     1975-08-25  Thailand    Australia           3           2
# ...          ...       ...          ...         ...         ...
# 4879  2022-07-22    Sweden      Belgium           1           0
# 4880  2022-07-23    France  Netherlands           1           0
# 4881  2022-07-26   England       Sweden           4           0
# 4882  2022-07-27   Germany       France           2           1
# 4883  2022-07-31   England      Germany           2           1
#
#             tournament home_continent away_continent
# 0                 Euro         Europe         Europe
# 1                 Euro         Europe         Europe
# 2                 Euro         Europe         Europe
# 3                 Euro         Europe         Europe
# 4     AFC Championship           Asia        Oceania
# ...                ...            ...            ...
# 4879         UEFA Euro         Europe         Europe
# 4880         UEFA Euro         Europe         Europe
# 4881         UEFA Euro         Europe         Europe
# 4882         UEFA Euro         Europe         Europe
# 4883         UEFA Euro         Europe         Europe
#
# [4884 rows x 8 columns]

# %%
# add a goal difference column 

df['goal_difference'] = np.abs(df['home_score'] - df['away_score'])

df
# Out:
#             date home_team    away_team  home_score  away_score  \
# 0     1969-11-01     Italy       France           1           0
# 1     1969-11-01   Denmark      England           4           3
# 2     1969-11-02   England       France           2           0
# 3     1969-11-02     Italy      Denmark           3           1
# 4     1975-08-25  Thailand    Australia           3           2
# ...          ...       ...          ...         ...         ...
# 4879  2022-07-22    Sweden      Belgium           1           0
# 4880  2022-07-23    France  Netherlands           1           0
# 4881  2022-07-26   England       Sweden           4           0
# 4882  2022-07-27   Germany       France           2           1
# 4883  2022-07-31   England      Germany           2           1
#
#             tournament home_continent away_continent  goal_difference
# 0                 Euro         Europe         Europe                1
# 1                 Euro         Europe         Europe                1
# 2                 Euro         Europe         Europe                2
# 3                 Euro         Europe         Europe                2
# 4     AFC Championship           Asia        Oceania                1
# ...                ...            ...            ...              ...
# 4879         UEFA Euro         Europe         Europe                1
# 4880         UEFA Euro         Europe         Europe                1
# 4881         UEFA Euro         Europe         Europe                4
# 4882         UEFA Euro         Europe         Europe                1
# 4883         UEFA Euro         Europe         Europe                1
#
# [4884 rows x 9 columns]

# %%
# who wins in a match --> add winer column 

df['winner'] = np.where(df['home_score'] > df['away_score'], df['home_team'],
                   np.where(df['away_score'] > df['home_score'], df['away_team'],
                   'Draw'))

df
# Out:
#             date home_team    away_team  home_score  away_score  \
# 0     1969-11-01     Italy       France           1           0
# 1     1969-11-01   Denmark      England           4           3
# 2     1969-11-02   England       France           2           0
# 3     1969-11-02     Italy      Denmark           3           1
# 4     1975-08-25  Thailand    Australia           3           2
# ...          ...       ...          ...         ...         ...
# 4879  2022-07-22    Sweden      Belgium           1           0
# 4880  2022-07-23    France  Netherlands           1           0
# 4881  2022-07-26   England       Sweden           4           0
# 4882  2022-07-27   Germany       France           2           1
# 4883  2022-07-31   England      Germany           2           1
#
#             tournament home_continent away_continent  goal_difference  \
# 0                 Euro         Europe         Europe                1
# 1                 Euro         Europe         Europe                1
# 2                 Euro         Europe         Europe                2
# 3                 Euro         Europe         Europe                2
# 4     AFC Championship           Asia        Oceania                1
# ...                ...            ...            ...              ...
# 4879         UEFA Euro         Europe         Europe                1
# 4880         UEFA Euro         Europe         Europe                1
# 4881         UEFA Euro         Europe         Europe                4
# 4882         UEFA Euro         Europe         Europe                1
# 4883         UEFA Euro         Europe         Europe                1
#
#         winner
# 0        Italy
# 1      Denmark
# 2      England
# 3        Italy
# 4     Thailand
# ...        ...
# 4879    Sweden
# 4880    France
# 4881   England
# 4882   Germany
# 4883   England
#
# [4884 rows x 10 columns]

# %%
# add year column
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year

df
# Out:
#            date home_team    away_team  home_score  away_score  \
# 0    1969-11-01     Italy       France           1           0
# 1    1969-11-01   Denmark      England           4           3
# 2    1969-11-02   England       France           2           0
# 3    1969-11-02     Italy      Denmark           3           1
# 4    1975-08-25  Thailand    Australia           3           2
# ...         ...       ...          ...         ...         ...
# 4879 2022-07-22    Sweden      Belgium           1           0
# 4880 2022-07-23    France  Netherlands           1           0
# 4881 2022-07-26   England       Sweden           4           0
# 4882 2022-07-27   Germany       France           2           1
# 4883 2022-07-31   England      Germany           2           1
#
#             tournament home_continent away_continent  goal_difference  \
# 0                 Euro         Europe         Europe                1
# 1                 Euro         Europe         Europe                1
# 2                 Euro         Europe         Europe                2
# 3                 Euro         Europe         Europe                2
# 4     AFC Championship           Asia        Oceania                1
# ...                ...            ...            ...              ...
# 4879         UEFA Euro         Europe         Europe                1
# 4880         UEFA Euro         Europe         Europe                1
# 4881         UEFA Euro         Europe         Europe                4
# 4882         UEFA Euro         Europe         Europe                1
# 4883         UEFA Euro         Europe         Europe                1
#
#         winner  year
# 0        Italy  1969
# 1      Denmark  1969
# 2      England  1969
# 3        Italy  1969
# 4     Thailand  1975
# ...        ...   ...
# 4879    Sweden  2022
# 4880    France  2022
# 4881   England  2022
# 4882   Germany  2022
# 4883   England  2022
#
# [4884 rows x 11 columns]

# %%
def win_percentage(df, country):
    # Home
    home_matches = df[df['home_team'] == country]
    home_wins = home_matches[home_matches['winner'] == country]
    home_win_per = round((len(home_wins) / len(home_matches)) * 100, 2) if len(home_matches) > 0 else 0.0

    # Away
    away_matches = df[df['away_team'] == country]
    away_wins = away_matches[away_matches['winner'] == country]
    away_win_per = round((len(away_wins) / len(away_matches)) * 100, 2) if len(away_matches) > 0 else 0.0

    # Total matches
    
    matches_played = len(home_matches) + len(away_matches)

    return {
        "country": country,
        "home_win_percent": home_win_per,
        "away_win_percent": away_win_per,
        "home matches": len(home_matches),
        "away_matches": len(away_matches),
        "total matches": matches_played
    }

# %%
# calculate win percentage by home and away team

all_countries = pd.unique(df[['home_team', 'away_team']].values.ravel())
results = [win_percentage(df, country) for country in all_countries]
win_percent = pd.DataFrame(results)
win_percent.head(5)
# Out:
#     country  home_win_percent  away_win_percent  home matches  away_matches  \
# 0     Italy             62.39             48.72           109           117
# 1    France             64.76             48.60           105           107
# 2   Denmark             59.17             43.71           120           151
# 3   England             67.59             49.50           108           101
# 4  Thailand             70.59             34.00            51            50
#
#    total matches
# 0            226
# 1            212
# 2            271
# 3            209
# 4            101

# %%
df.to_csv('women_results.csv', index=False)

# %%
df.to_csv('women_win_percent.csv', index=False)
