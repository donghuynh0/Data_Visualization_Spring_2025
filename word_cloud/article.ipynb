# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
url_a1 = "http://115.78.93.252/TTU/pool/donghuynh0/data_visulization_2025/data/ArticlesJan2017.csv"
url_a2 = "http://115.78.93.252/TTU/pool/donghuynh0/data_visulization_2025/data/ArticlesFeb2017.csv"
url_a3 = "http://115.78.93.252/TTU/pool/donghuynh0/data_visulization_2025/data/ArticlesMarch2017.csv"
url_a4 = "http://115.78.93.252/TTU/pool/donghuynh0/data_visulization_2025/data/ArticlesApril2017.csv"
url_a5 = "http://115.78.93.252/TTU/pool/donghuynh0/data_visulization_2025/data/ArticlesMay2017.csv"
url_a6 = "http://115.78.93.252/TTU/pool/donghuynh0/data_visulization_2025/data/ArticlesJan2018.csv"
url_a7 = "http://115.78.93.252/TTU/pool/donghuynh0/data_visulization_2025/data/ArticlesFeb2018.csv"
url_a8 = "http://115.78.93.252/TTU/pool/donghuynh0/data_visulization_2025/data/ArticlesMarch2018.csv"
url_a9 = "http://115.78.93.252/TTU/pool/donghuynh0/data_visulization_2025/data/ArticlesApril2018.csv"



a1 = pd.read_csv(url_a1)
a2 = pd.read_csv(url_a2)
a3 = pd.read_csv(url_a3)
a4 = pd.read_csv(url_a4)
a5 = pd.read_csv(url_a5)
a6 = pd.read_csv(url_a6)
a7 = pd.read_csv(url_a7)
a8 = pd.read_csv(url_a8)
a9 = pd.read_csv(url_a9)

articles = pd.concat([a1, a2, a3, a4, a5, a6, a7, a8, a9])
articles.drop_duplicates(subset='articleID', inplace=True)

# %%
articles.shape
# Out:
# (9298, 16)

# %%
headlines = str(articles.headline)

# %%
stopwords = set(STOPWORDS)
more_stopwords = {'one', 'br', 'Po', 'th', 'sayi', 'fo', 'Unknown', 's', 'o', 'g', 'p' , 'pre'}
stopwords = stopwords.union(more_stopwords)

# %%
wordcloud = WordCloud(
    stopwords = stopwords,
    background_color='white'
).generate(headlines)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Most common words in the headlines on the articles',
         fontdict={'size': 26, 'color': 'green', 'verticalalignment': 'bottom'})
plt.show()
